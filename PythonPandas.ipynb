# %%
import numpy as np
import pandas as pd 
import matplotlib as mlt

url = "https://raw.githubusercontent.com/afizing/DataSources/master/train.csv"
data = pd.read_csv(url, index_col="Loan_ID")
data.head(1)
# Out:
#          Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# Loan_ID
# LP001002   Male      No          0  Graduate            No             5849
#
#           CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# Loan_ID
# LP001002                  0         NaN               360               1
#
#          Property_Area Loan_Status
# Loan_ID
# LP001002         Urban           Y

# %%
data.loc[(data["Gender"]=="Female") & (data["Education"]=="Not Graduate") & (data["Loan_Status"]=="Y"), ["Gender","Education","Loan_Status"]]
# Out:
#           Gender     Education Loan_Status
# Loan_ID
# LP001155  Female  Not Graduate           Y
# LP001669  Female  Not Graduate           Y
# LP001692  Female  Not Graduate           Y
# LP001908  Female  Not Graduate           Y
# LP002300  Female  Not Graduate           Y
# LP002314  Female  Not Graduate           Y
# LP002407  Female  Not Graduate           Y
# LP002489  Female  Not Graduate           Y
# LP002502  Female  Not Graduate           Y
# LP002534  Female  Not Graduate           Y
# LP002582  Female  Not Graduate           Y
# LP002731  Female  Not Graduate           Y
# LP002757  Female  Not Graduate           Y
# LP002917  Female  Not Graduate           Y

# %%
#Create a new function 
def missing(x):
    return sum(x.isnull())

#Applying per column 
print "Missing Values per column"
print data.apply(missing, axis=0)

#Applying per Row 
print "\n\nMissing Values per Row"
print data.apply(missing, axis=1).head(10) #axis=1 defines to apply on row
# Out:
# Missing Values per column
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64
#
#
# Missing Values per Row
# Loan_ID
# LP001002    1
# LP001003    0
# LP001005    0
# LP001006    0
# LP001008    0
# LP001011    0
# LP001013    0
# LP001014    0
# LP001018    0
# LP001020    0
# dtype: int64

# %%
data.dtypes
# Out:
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
data.index
# Out:
# Index([u'LP001002', u'LP001003', u'LP001005', u'LP001006', u'LP001008',
#        u'LP001011', u'LP001013', u'LP001014', u'LP001018', u'LP001020',
#        ...
#        u'LP002959', u'LP002960', u'LP002961', u'LP002964', u'LP002974',
#        u'LP002978', u'LP002979', u'LP002983', u'LP002984', u'LP002990'],
#       dtype='object', name=u'Loan_ID', length=614)

# %%
data.columns
# Out:
# Index([u'Gender', u'Married', u'Dependents', u'Education', u'Self_Employed',
#        u'ApplicantIncome', u'CoapplicantIncome', u'LoanAmount',
#        u'Loan_Amount_Term', u'Credit_History', u'Property_Area',
#        u'Loan_Status'],
#       dtype='object')

# %%
data.T
# Out:
# Loan_ID            LP001002  LP001003  LP001005      LP001006  LP001008  \
# Gender                 Male      Male      Male          Male      Male
# Married                  No       Yes       Yes           Yes        No
# Dependents                0         1         0             0         0
# Education          Graduate  Graduate  Graduate  Not Graduate  Graduate
# Self_Employed            No        No       Yes            No        No
# ApplicantIncome        5849      4583      3000          2583      6000
# CoapplicantIncome         0      1508         0          2358         0
# LoanAmount              NaN       128        66           120       141
# Loan_Amount_Term        360       360       360           360       360
# Credit_History            1         1         1             1         1
# Property_Area         Urban     Rural     Urban         Urban     Urban
# Loan_Status               Y         N         Y             Y         Y
#
# ...

# %%
data.sort_index(axis=1, ascending=False)
# Out:
#          Self_Employed Property_Area Married Loan_Status  Loan_Amount_Term  \
# Loan_ID
# LP001002            No         Urban      No           Y               360
# LP001003            No         Rural     Yes           N               360
# LP001005           Yes         Urban     Yes           Y               360
# LP001006            No         Urban     Yes           Y               360
# LP001008            No         Urban      No           Y               360
# LP001011           Yes         Urban     Yes           Y               360
# LP001013            No         Urban     Yes           Y               360
# LP001014            No     Semiurban     Yes           N               360
# LP001018            No         Urban     Yes           Y               360
# LP001020            No     Semiurban     Yes           N               360
# LP001024            No         Urban     Yes           Y               360
# ...

# %%
data.sort_index(axis=0, ascending=False).head()
# Out:
#           Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# Loan_ID
# LP002990  Female      No          0  Graduate           Yes             4583
# LP002984    Male     Yes          2  Graduate            No             7583
# LP002983    Male     Yes          1  Graduate            No             8072
# LP002979    Male     Yes         3+  Graduate            No             4106
# LP002978  Female      No          0  Graduate            No             2900
#
#           CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# Loan_ID
# LP002990                  0         133               360               0
# LP002984                  0         187               360               1
# LP002983                240         253               360               1
# LP002979                  0          40               180               1
# LP002978                  0          71               360               1
#
#          Property_Area Loan_Status
# ...

# %%
#Sorting by values 
data.sort_values(by='ApplicantIncome').tail()
# Out:
#          Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# Loan_ID
# LP001640   Male     Yes          0  Graduate           Yes            39147
# LP001536   Male     Yes         3+  Graduate            No            39999
# LP001585    NaN     Yes         3+  Graduate            No            51763
# LP002101   Male     Yes          0  Graduate           NaN            63337
# LP002317   Male     Yes         3+  Graduate            No            81000
#
#           CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# Loan_ID
# LP001640               4750         120               360               1
# LP001536                  0         600               180               0
# LP001585                  0         700               300               1
# LP002101                  0         490               180               1
# LP002317                  0         360               360               0
#
#          Property_Area Loan_Status
# ...

# %%
## Selection 
data['Gender'].head()
# Out:
# Loan_ID
# LP001002    Male
# LP001003    Male
# LP001005    Male
# LP001006    Male
# LP001008    Male
# Name: Gender, dtype: object

# %%
data['LP001002':'LP001005']
# Out:
#          Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# Loan_ID
# LP001002   Male      No          0  Graduate            No             5849
# LP001003   Male     Yes          1  Graduate            No             4583
# LP001005   Male     Yes          0  Graduate           Yes             3000
#
#           CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# Loan_ID
# LP001002                  0         NaN               360               1
# LP001003               1508         128               360               1
# LP001005                  0          66               360               1
#
#          Property_Area Loan_Status
# Loan_ID
# LP001002         Urban           Y
# LP001003         Rural           N
# LP001005         Urban           Y

# %%
data.loc[:, ['Gender', 'Married']].head()
# Out:
#          Gender Married
# Loan_ID
# LP001002   Male      No
# LP001003   Male     Yes
# LP001005   Male     Yes
# LP001006   Male     Yes
# LP001008   Male      No

# %%
data.iloc[2:5, 0:3]
# Out:
#          Gender Married Dependents
# Loan_ID
# LP001005   Male     Yes          0
# LP001006   Male     Yes          0
# LP001008   Male      No          0

# %%
#Boolean Indexing 

data[data['Gender']=='Male'].head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                  0         NaN               360
# LP001003             4583               1508         128               360
# LP001005             3000                  0          66               360
# LP001006             2583               2358         120               360
# LP001008             6000                  0         141               360
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002               1         Urban           Y
# ...

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102', periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
data.count()
# Out:
# Gender               601
# Married              611
# Dependents           599
# Education            614
# Self_Employed        582
# ApplicantIncome      614
# CoapplicantIncome    614
# LoanAmount           592
# Loan_Amount_Term     600
# Credit_History       564
# Property_Area        614
# Loan_Status          614
# dtype: int64

# %%
data1 = data.copy()

# %%
pure_data = data1.dropna(how='any').copy()

# %%
pure_data.count()
# Out:
# Gender               480
# Married              480
# Dependents           480
# Education            480
# Self_Employed        480
# ApplicantIncome      480
# CoapplicantIncome    480
# LoanAmount           480
# Loan_Amount_Term     480
# Credit_History       480
# Property_Area        480
# Loan_Status          480
# dtype: int64

# %%
data.columns
# Out:
# Index([u'Gender', u'Married', u'Dependents', u'Education', u'Self_Employed',
#        u'ApplicantIncome', u'CoapplicantIncome', u'LoanAmount',
#        u'Loan_Amount_Term', u'Credit_History', u'Property_Area',
#        u'Loan_Status'],
#       dtype='object')

# %%
data['Gender'].dropna().count()
# Out:
# 601

# %%
l = [x for x in range(10)]

# %%
a = [23,121]
l.extend(a)
l.sort()
l.reverse()
l
# Out:
# [121, 121, 121, 121, 121, 23, 23, 23, 23, 23, 9, 8, 7, 6, 5, 4, 3, 2, 1, 0]
